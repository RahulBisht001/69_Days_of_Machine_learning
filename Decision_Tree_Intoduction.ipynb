# %% [markdown]
# <a href="https://colab.research.google.com/github/RahulBisht001/69_Days_of_Machine_learning/blob/main/Decision_Tree_Intoduction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **✅Decision Trees**

# %% [markdown]
# A Decision tree is a flowchart-like structure in which each internal node represents a "test" on an attribute (e.g. whether a coin flip comes up heads or tails), each branch represents the outcome of the test, and each leaf node represents a class label (decision taken after computing all attributes).

# %% [markdown]
# **Decision Tree Diagram**
#
#
# <img src="https://365datascience.com/resources/blog/59utffqewug-decision-trees-image2.png" alt="Decision Tree" width="500" height="auto"/>

# %% [markdown]
# How we can build our own Decision Tree.
#
# **Pseduo code**
#
# 1.   Begin with the training dataset which should have some feature variables and **classification** or **Regression** output.
#
# 2.   Determine the **best feature** in the dataset to split the data on.
#
# 3. Split the data into subsets that contains the correct value for this **best feature**.This splitting basically defines a node on the tree i.e each node is a splitting point based on certain feature from our data.
#
# 4. Recusively generates new Tree node by using the subset of data created at step 3.

# %% [markdown]
# ### **Explaination**
#
# **Mathematical Explaination**
#
# Decision Trees uses ***hyperplains*** which run ***parallel to any on of the axis*** to cut your coordinate system into hyper ***cuboids***.
#
#
#
#
# ---
#
#
# **Programatically**:
#
# Decision trees are nothing but a gaint structure of nested if-else conditions.

# %% [markdown]
# **Advantages and Disadvantages for Decision Trees.**

# %% [markdown]
# ---

# %% [markdown]
# ###🤔**Entropy in Decision Tree**

# %% [markdown]
# In the context of Decision Trees, **entropy** is a measure of disorder or impurity in a node. Thus, a node with more variable composition, such as 2Pass and 2 Fail would be considered to have higher Entropy than a node which has only pass or only fail.
#
# ---
# In layman terms **Entropy** is nothing but **the measure of disorder**
#
# ---
# More Knowledge = less Entropy

# %% [markdown]
# ### **🤯How to Calulate Entropy**
#
# *Mathematical Formula* :
#
# $$E(S) = \sum_{i=1}^{c} -P(i) \log_{2}(P(i))$$
# ---
#
# - where this \$P_{i}$  is nothing but frequentist probability of an element/class in the data.
#
# * For Example if our data have only two class label yes or no.(eg: she love me or not [ Only yes and no 2 Categories ] )
#
# $$E(D) = -p_{yes} \log_{2}(p_{yes})-p_{no} \log_{2}(p_{no})$$

# %% [markdown]
# ### **👀 Observations**
#
# - More the **Uncertainity** more the **Entropy**.
# - For a 2 class problem the **min Entropty** is 0 and **max Entropy** is 1 but it not hold good more than 2 class. in more than 2 class problem the entropy can be more than 1.
# - we can use both  $\log_{2}$  or $\log_{e}$  for calculating Entropies.

# %% [markdown]
# #### **Entropy vs Probability**
#
# It is simitrical as it is for a 2 class problem (Yes or No Type)

# %% [markdown]
# <img src="https://miro.medium.com/v2/resize:fit:565/1*M15RZMSk8nGEyOnD8haF-A.png" alt="entropy-in-machine-learning.png" width="500" height="300">

# %% [markdown]
# #### Entropy for Continious Variables.
#
# Less Peek = Higher Entropy (High Disorders)
#
#
# ---

# %% [markdown]
# ### **📚Information Gain**
#
# **Information Gain** is a Matric used to train Decision Trees.Specifically ,this matric measures the **quality of split**.
#
# ---
#
# The Information gain is based on the decrease in the entropy after the dataset is split on an attribute. Constructing a Decision Tree is all about finding attributes that return highest infomation Gain
#
# $$ Information \ Gain = E(Parent) - Weighted Average * E(children)  $$
#
# ---
# - Watch the CampusX Video for numerical
#
# Steps for the Getting information gain
#
#
# 1.   Calculate Entropy of Parent $\ E_{parent}$
# 2.   Split the according to the attributes of the column which you have choose and the find out the
# $\ E_{children}$
# 3.  Calculate Weighted Entropy of the children.
#
#     $Weighted Entropy = (values \ in \ the \ child \ column / \ total \ values) * E_{children} $
#     -
# 4. Calcute the **information gain** by formula.
#
# 5. Calculate the infomation gain for all the input columns and the algorithm will select the column with highest infomation gain.
# 6. Find information gain recursively
#
# * Decision tree than applies a ***recursive greedy search algorithm*** in top to bottom fashion to find the information gain at each level of tree.
# * Once the entropy comes 0 no more splitting is done.

# %% [markdown]
# ### **🎯Gini Impurity**
#
# Just like Information Gain Gini Impurity is another measure of quality of split.
#
# *formula:*
#
# $$ G_{I} = 1 - (P_{y}^2 +\ P_{n}^2)$$
# --
#
# Information gain is same as Entropy.
#
#
# $$ Information \ Gain = G_{i}(Parent) - Weighted Average * G_{i}(children)  $$
#
# ---
# ---
# After all both gini and Entropy are giving same result but gini is computationally fast. but some cases entropy gives us a better balanced tree so more or less we should be hyperparametertuning and figure out that which method is working better.

# %% [markdown]
# #### **📍Some Good Discussions.**
#
# * [Why in some Cased entropy gives a more Balanced Tree](https://sebastianraschka.com/faq/docs/decision-tree-binary.html)

# %% [markdown]
# ### **🔢 Handling the Numerical Values in Decision Tree**
#
#
# Calculating N Unique values may not be the best approach
# Why ?
# Because what if we have all N Unique values.
#
# ---
#
#
# *   Sort the data on basis of numerical data.
# *   Split the Entire data on basis of every value of numerical column.
#
# * Watch  video
#
# handling Numerical values is computationally expensive and the train time complexity can be much higher but test time complexity is still $ \ log_{e}(N)$

# %% [markdown]
# ### **🌳Visualization of a Decision Tree**

# %%
from sklearn.datasets import load_iris
import seaborn as sns

# %%
# iris = sns.load_dataset('iris')
# iris.sample(5)

iris = load_iris()
X = iris.data
targetNames = iris.target_names
# print(targetNames)
y = iris.target
# y

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
X_train.shape
# Out:
# (120, 4)

# %%
y_train.shape
# Out:
# (120,)

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier()

clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)
# y_pred

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9666666666666667

# %%
from sklearn.tree import plot_tree

# %%
from matplotlib.pylab import rcParams

rcParams['figure.figsize'] = 80,50

plot_tree(clf)
# Out:
# [Text(0.4444444444444444, 0.9166666666666666, 'x[2] <= 2.45\ngini = 0.665\nsamples = 120\nvalue = [43, 37, 40]'),
#  Text(0.3333333333333333, 0.75, 'gini = 0.0\nsamples = 43\nvalue = [43, 0, 0]'),
#  Text(0.5555555555555556, 0.75, 'x[3] <= 1.75\ngini = 0.499\nsamples = 77\nvalue = [0, 37, 40]'),
#  Text(0.4444444444444444, 0.5833333333333334, 'x[2] <= 4.95\ngini = 0.21\nsamples = 42\nvalue = [0, 37, 5]'),
#  Text(0.2222222222222222, 0.4166666666666667, 'x[3] <= 1.65\ngini = 0.054\nsamples = 36\nvalue = [0, 35, 1]'),
#  Text(0.1111111111111111, 0.25, 'gini = 0.0\nsamples = 35\nvalue = [0, 35, 0]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.6666666666666666, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.5555555555555556, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.7777777777777778, 0.25, 'x[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
# ...
